# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 10</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    a=int(input("Enter number:"))
    b=int(input("Enter number:"))
    c=a/b
    print(a/b)
except ZeroDivisionError:
    print("Not divisible by zero")
except ValueError:
    print("Values error")
except TypeError:
    print("Type error")
# Out:
# Enter number: 12
# Enter number: 0
# Not divisible by zero

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try:
    size=int(input("enter size"))
    li=[]
    for i in range(size):
        n=int(input("enter number:"))
        li.append(n)
    print(li)
    index=int(input("enter index"))
    print(li[index])
except IndexError:
    print("index out of bound.......")
# Out:
# enter size 2
# enter number: 1
# enter number: 2
# [1, 2]
# enter index 3
# index out of bound.......

# %%
try:
    size=int(input("enter size of dict:"))
    s1=dict()
    for i in range(size):
        key=int(input("enter key"))
        value=input("enter value")
        s1[key]=value
    searchKey=int(input("enter key"))
    s1[searchKey]
except KeyError:
    print("Key error ocuured....")
# Out:
# enter size of dict: 1
# enter key 1
# enter value name
# enter key 2
# Key error ocuured....

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    fp=open("firstFile.txt","r")
    fp.read()
except FileNotFoundError:
    print("File not found erro ocuuured.....")
# Out:
# File not found erro ocuuured.....

# %%
try:
    import some
except ModuleNotFoundError:
    print("Module not found....")
# Out:
# Module not found....

# %% [markdown]
# ### 04) WAP that catches all type of exceptions in a single except block.

# %%
try:
    a = int(input("Enter first number : "))
    b = int(input("Enter second number : "))
    c = a // b
    print(c)
except (ZeroDivisionError, ValueError ,TypeError) as err:
    print("type(err) = ",type(err))
    print("error = ",err)
    print("err.args = ",err.args)
    print("err.args[0] = ",err.args[0])
    print("str(err) = ",str(err))
    print("err.__str__() = ",err.__str__())
# Out:
# Enter first number :  1
# Enter second number :  0
# type(err) =  <class 'ZeroDivisionError'>
# error =  integer division or modulo by zero
# err.args =  ('integer division or modulo by zero',)
# err.args[0] =  integer division or modulo by zero
# str(err) =  integer division or modulo by zero
# err.__str__() =  integer division or modulo by zero

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    fp=open("third.txt","r")
except (FileNotFoundError,ModuleNotFoundError) as err:
    print(err)
else:
    print(fp.read())
finally:
    print("This block will be excecuted every time")
# Out:
# [Errno 2] No such file or directory: 'third.txt'
# This block will be excecuted every time

# %% [markdown]
# ### 06) Create a short program that prompts the user for a list of grades separated by commas.
# ### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# ### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
try:
    str_marks=input("enter marks seprated by coma")
    li_marks=str_marks.split(",")
     #print(li_marks)
    l1=[int(i) for i in li_marks]
    print(l1)
except ValueError:
    print(" Value Error.....")
# Out:
# enter marks seprated by coma enwb
#  Value Error.....

# %% [markdown]
# ### 07) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def HandelZeroDivision( a, b):
    try:
        c=a/b
        print(c)
    except ZeroDivisionError:
        print("Zero Division Error....")

# %%
HandelZeroDivision(1,0)
# Out:
# Zero Division Error....

# %% [markdown]
# ### 08) WAP that gets an age of a person form the user and raises ValueError with error message: "Enter Valid Age" :
# #### If the age is less than 18.
# #### otherwise print the age.

# %%
class ValidAgeError(Exception):
    pass
try:
    age=int(input("entre age of the person:"))
    if age<18:
        raise ValidAgeError
    else:
        print("welcome to the world")
except ValidAgeError:
    print("Enter valid age...")
# Out:
# entre age of the person: 1
# Enter valid age...

# %% [markdown]
# ### 09) WAP to raise your custom Exception named InvalidUsernameError with the error message : "Username must be between 5 and 15 characters long":
# #### if the given name is having characters less than 5 or greater than 15.
# #### otherwise print the given username.

# %%
class InvalidUsernameError(Exception):
    pass
try:
    username=input("enter username:")
    if len(username)<5 or len(username)>15:
        raise InvalidUsernameError
    else:
        print("Successfully Login....",username)
except InvalidUsernameError:
    print("invalid.....")
# Out:
# enter username: fgda
# invalid.....

# %% [markdown]
# ### 10) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
import math
def NegativeNumberError(Exception):
    pass
try:
    num=int(input("enter number:"))
    if(num<0):
        raise NegativeNumberError
    else:
        ans=math.sqrt(num)
    print(f"Square Root of {num} is {ans}")
except:
    print("Cannot calculate the square root of a negative number...!!")
# Out:
# enter number: -1
# Cannot calculate the square root of a negative number...!!
